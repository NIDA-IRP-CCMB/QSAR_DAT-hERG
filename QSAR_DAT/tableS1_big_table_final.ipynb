# %%
from convert_csv_to_ipynb import *
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>DrugBank ID</th>
#       <th>DAT</th>
#       <th>SERT</th>
#       <th>NET</th>
#       <th>DAT-SERT</th>
#       <th>DAT-NET</th>
#       <th>selective</th>
#       <th>cluster id</th>
#       <th>source</th>
#       <th>source before replacement</th>
#       <th>doi (DAT)</th>
#       <th>doi (SERT)</th>
#       <th>doi (NET)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>vanoxerine#</td>
#       <td>DB03701</td>
#       <td>10.22</td>
#       <td>7.62</td>
#       <td>7.1</td>
#       <td>2.6</td>
#       <td>3.12</td>
#       <td>DAT selective</td>
#       <td>D</td>
#       <td>ChEMBL</td>
#       <td>ChEMBL</td>
#       <td><a href="https://doi.org/10.1021/jm9505324" target="_blank">https://doi.org/10.1021/jm9505324</a></td>
# ...
